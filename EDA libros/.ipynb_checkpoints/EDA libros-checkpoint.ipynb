# %%
import pandas as pd #analisis de datos
import numpy as np  #carga de datos
import matplotlib.pyplot as plt #graficas

# %%
df = pd.read_csv('libros_toscrape_pag1.csv')
print("carga de datos exitosa")
# Out:
# carga de datos exitosa

# %%
df.head(10)
# Out:
#                                               titulo  precio_gbp  \
# 0                               A Light in the Attic       51.77
# 1                                 Tipping the Velvet       53.74
# 2                                         Soumission       50.10
# 3                                      Sharp Objects       47.82
# 4              Sapiens: A Brief History of Humankind       54.23
# 5                                    The Requiem Red       22.65
# 6  The Dirty Little Secrets of Getting Your Dream...       33.34
# 7  The Coming Woman: A Novel Based on the Life of...       17.93
# 8  The Boys in the Boat: Nine Americans and Their...       22.60
# 9                                    The Black Maria       52.15
#
#   disponibilidad  rating                                             enlace
# 0       In stock       3  https://books.toscrape.com/catalogue/a-light-i...
# 1       In stock       1  https://books.toscrape.com/catalogue/tipping-t...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   titulo          20 non-null     str
#  1   precio_gbp      20 non-null     float64
#  2   disponibilidad  20 non-null     str
#  3   rating          20 non-null     int64
#  4   enlace          20 non-null     str
# dtypes: float64(1), int64(1), str(3)
# memory usage: 3.4 KB

# %%
df.describe()import seaborn as sns
sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"]=(10,6)
# Out:
#        precio_gbp     rating
# count   20.000000  20.000000
# mean    38.048500   2.850000
# std     15.135231   1.565248
# min     13.990000   1.000000
# 25%     22.637500   1.000000
# 50%     41.380000   3.000000
# 75%     51.865000   4.000000
# max     57.250000   5.000000

# %%
import seaborn as sns
sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"]=(15,6)

# %%
#variable objetivo
sns.countplot(x="rating", data=df)
plt.title("Distribucion por rating")
plt.show()

# %%
#variable objetivo
sns.countplot(x="precio_gbp", data=df)
plt.title("Distribucion por precio")
plt.show()
